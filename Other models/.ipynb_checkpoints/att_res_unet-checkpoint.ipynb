# %%
import os
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from datetime import datetime 
import cv2
from PIL import Image
from keras import backend, optimizers


image_directory = 'Train/images/'
mask_directory = 'Train/masks/'


SIZE = 256
image_dataset = []  #Many ways to handle data, you can use pandas. Here, we are using a list format.  
mask_dataset = []  #Place holders to define add labels. We will add 0 to all parasitized images and 1 to uninfected.

images = os.listdir(image_directory)
for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'tif'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory+image_name, 1)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        image_dataset.append(np.array(image))

#Iterate through all images in Uninfected folder, resize to 64 x 64
#Then save into the same numpy array 'dataset' but with label 1

masks = os.listdir(mask_directory)
for i, image_name in enumerate(masks):
    if (image_name.split('.')[1] == 'tif'):
        image = cv2.imread(mask_directory+image_name, 0)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        mask_dataset.append(np.array(image))


#Normalize images
image_dataset = np.array(image_dataset)/255.
#D not normalize masks, just rescale to 0 to 1.
mask_dataset = np.expand_dims((np.array(mask_dataset)),3) /255.



from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, test_size = 0.10, random_state = 0)

#Sanity check, view few mages
import random
import numpy as np
image_number = random.randint(0, len(X_train))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(np.reshape(X_train[image_number], (256, 256, 3)), cmap='gray')
plt.subplot(122)
plt.imshow(np.reshape(y_train[image_number], (256, 256)), cmap='gray')
plt.show()

#######################################
#Parameters for model

IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH  = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]
num_labels = 1  #Binary
input_shape = (IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)
batch_size = 8

#FOCAL LOSS AND DICE METRIC
#Focal loss helps focus more on tough to segment classes.
from focal_loss import BinaryFocalLoss

###############################################################################


#Try various models: Unet, Attention_UNet, and Attention_ResUnet
#Rename original python file from 224_225_226_models.py to models.py
from models import Attention_ResUNet, UNet, Attention_UNet, dice_coef, dice_coef_loss, jacard_coef

# '''
# UNet
# '''
# unet_model = UNet(input_shape)
# unet_model.compile(optimizer=Adam(lr = 1e-2), loss=BinaryFocalLoss(gamma=2), 
#               metrics=['accuracy', jacard_coef])


# print(unet_model.summary())

# start1 = datetime.now() 
# unet_history = unet_model.fit(X_train, y_train, 
#                     verbose=1,
#                     batch_size = batch_size,
#                     validation_data=(X_test, y_test ), 
#                     shuffle=False,
#                     epochs=50)

# stop1 = datetime.now()
# #Execution time of the model 
# execution_time_Unet = stop1-start1
# print("UNet execution time is: ", execution_time_Unet)

# unet_model.save('mitochondria_UNet_50epochs_B_focal.hdf5')
# #____________________________________________
# '''
# Attention UNet
# '''
# att_unet_model = Attention_UNet(input_shape)

# att_unet_model.compile(optimizer=Adam(lr = 1e-2), loss=BinaryFocalLoss(gamma=2), 
#               metrics=['accuracy', jacard_coef])


# print(att_unet_model.summary())
# start2 = datetime.now() 
# att_unet_history = att_unet_model.fit(X_train, y_train, 
#                     verbose=1,
#                     batch_size = batch_size,
#                     validation_data=(X_test, y_test ), 
#                     shuffle=False,
#                     epochs=50)
# stop2 = datetime.now()
# #Execution time of the model 
# execution_time_Att_Unet = stop2-start2
# print("Attention UNet execution time is: ", execution_time_Att_Unet)

# att_unet_model.save('mitochondria_Attention_UNet_50epochs_B_focal.hdf5')

# #___________________________________________
# '''
# Attention Residual Unet
# '''
att_res_unet_model = Attention_ResUNet(input_shape)

att_res_unet_model.compile(optimizer=Adam(lr = 1e-2), loss=BinaryFocalLoss(gamma=2), 
              metrics=['accuracy', jacard_coef])


# att_res_unet_model.compile(optimizer=Adam(lr = 1e-3), loss='binary_crossentropy', 
#               metrics=['accuracy', jacard_coef])

print(att_res_unet_model.summary())


start3 = datetime.now() 
att_res_unet_history = att_res_unet_model.fit(X_train, y_train, 
                    verbose=1,
                    batch_size = batch_size,
                    validation_data=(X_test, y_test ), 
                    shuffle=False,
                    epochs=10)
stop3 = datetime.now()

#Execution time of the model 
execution_time_AttResUnet = stop3-start3
print("Attention ResUnet execution time is: ", execution_time_AttResUnet)

att_res_unet_model.save('mitochondria_AttResUnet_50epochs_B_focal.hdf5')

############################################################################
# convert the history.history dict to a pandas DataFrame and save as csv for
# future plotting
import pandas as pd    
unet_history_df = pd.DataFrame(unet_history.history) 
att_unet_history_df = pd.DataFrame(att_unet_history.history) 
att_res_unet_history_df = pd.DataFrame(att_res_unet_history.history) 

# with open('unet_history_df.csv', mode='w') as f:
#     unet_history_df.to_csv(f)
    
# with open('att_unet_history_df.csv', mode='w') as f:
#     att_unet_history_df.to_csv(f)

with open('custom_code_att_res_unet_history_df.csv', mode='w') as f:
    att_res_unet_history_df.to_csv(f)    

#######################################################################
#Check history plots, one model at a time
# history = unet_history
# history = att_unet_history
history = att_res_unet_history

#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['jacard_coef']
#acc = history.history['accuracy']
val_acc = history.history['val_jacard_coef']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training Jacard')
plt.plot(epochs, val_acc, 'r', label='Validation Jacard')
plt.title('Training and validation Jacard')
plt.xlabel('Epochs')
plt.ylabel('Jacard')
plt.legend()
plt.show()

#######################################################



# model = unet_model
# model = att_unet_model
model = att_res_unet_model

# model_path = "models/mitochondria_UNet_50epochs_B_focal.hdf5"
# model_path = "models/mitochondria_Attention_UNet_50epochs_B_focal.hdf5"
model_path = "models/mitochondria_AttResUnet_50epochs_B_focal.hdf5"
#Load one model at a time for testing.
model = tf.keras.models.load_model(model_path, compile=False)


import random
test_img_number = random.randint(0, X_test.shape[0]-1)
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]

test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img, cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()


#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())


#Calculate IoU for all test images and average
 
import pandas as pd

IoU_values = []
for img in range(0, X_test.shape[0]):
    temp_img = X_test[img]
    ground_truth=y_test[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,:,:,0] > 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
# Out:
# Model: "UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  640         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 16, 16, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 16, 16, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  up_sampling2d (UpSampling2D)   (None, 32, 32, 1024  0           ['activation_9[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 32, 32, 1536  0           ['up_sampling2d[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 512)  7078400     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0          ['activation_11[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 768)  0           ['up_sampling2d_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 256)  1769728     ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_13[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 25  0          ['activation_13[0][0]']
#                                 6)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 38  0           ['up_sampling2d_2[0][0]',
#                                 4)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 12  442496      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 12  0          ['activation_15[0][0]']
#                                 8)
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 19  0           ['up_sampling2d_3[0][0]',
#                                 2)                                'activation_1[0][0]']
#  conv2d_16 (Conv2D)             (None, 256, 256, 64  110656      ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 256, 256, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 1)  65          ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 256, 256, 1)  4          ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 256, 256, 1)  0           ['batch_normalization_18[0][0]']
#
# ==================================================================================================
# Total params: 31,401,349
# Trainable params: 31,389,571
# Non-trainable params: 11,778
# __________________________________________________________________________________________________
# None
# Model: "AttentionResUNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 64  1792        ['input_2[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 256, 256, 64  256        ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 256, 256, 64  256         ['input_2[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 256, 256, 64  36928       ['activation_19[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 256, 256, 64  256        ['conv2d_21[0][0]']
#  ormalization)                  )
#
#  batch_normalization_20 (BatchN  (None, 256, 256, 64  256        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  add (Add)                      (None, 256, 256, 64  0           ['batch_normalization_21[0][0]',
#                                 )                                 'batch_normalization_20[0][0]']
#
#  activation_20 (Activation)     (None, 256, 256, 64  0           ['add[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 64  0          ['activation_20[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 12  73856       ['max_pooling2d_4[0][0]']
#                                 8)
#
#  batch_normalization_22 (BatchN  (None, 128, 128, 12  512        ['conv2d_22[0][0]']
#  ormalization)                  8)
#
#  activation_21 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_22[0][0]']
#                                 8)
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 12  8320        ['max_pooling2d_4[0][0]']
#                                 8)
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 12  147584      ['activation_21[0][0]']
#                                 8)
#
#  batch_normalization_24 (BatchN  (None, 128, 128, 12  512        ['conv2d_24[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_23 (BatchN  (None, 128, 128, 12  512        ['conv2d_23[0][0]']
#  ormalization)                  8)
#
#  add_1 (Add)                    (None, 128, 128, 12  0           ['batch_normalization_24[0][0]',
#                                 8)                                'batch_normalization_23[0][0]']
#
#  activation_22 (Activation)     (None, 128, 128, 12  0           ['add_1[0][0]']
#                                 8)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 128)  0          ['activation_22[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 256)  295168      ['max_pooling2d_5[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 256)  33024       ['max_pooling2d_5[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_23[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_27[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_26[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 64, 64, 256)  0           ['batch_normalization_27[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  activation_24 (Activation)     (None, 64, 64, 256)  0           ['add_2[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 256)  0          ['activation_24[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 512)  1180160     ['max_pooling2d_6[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 512)  131584      ['max_pooling2d_6[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_25[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_29[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 32, 32, 512)  0           ['batch_normalization_30[0][0]',
#                                                                   'batch_normalization_29[0][0]']
#
#  activation_26 (Activation)     (None, 32, 32, 512)  0           ['add_3[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 512)  0          ['activation_26[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 16, 16, 1024  4719616     ['max_pooling2d_7[0][0]']
#                                 )
#
#  batch_normalization_31 (BatchN  (None, 16, 16, 1024  4096       ['conv2d_31[0][0]']
#  ormalization)                  )
#
#  activation_27 (Activation)     (None, 16, 16, 1024  0           ['batch_normalization_31[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 1024  525312      ['max_pooling2d_7[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 16, 16, 1024  9438208     ['activation_27[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 16, 16, 1024  4096       ['conv2d_33[0][0]']
#  ormalization)                  )
#
#  batch_normalization_32 (BatchN  (None, 16, 16, 1024  4096       ['conv2d_32[0][0]']
#  ormalization)                  )
#
#  add_4 (Add)                    (None, 16, 16, 1024  0           ['batch_normalization_33[0][0]',
#                                 )                                 'batch_normalization_32[0][0]']
#
#  activation_28 (Activation)     (None, 16, 16, 1024  0           ['add_4[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 16, 16, 512)  524800      ['activation_28[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 512)  262656      ['activation_29[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 512)  2359808    ['conv2d_36[0][0]']
#  ose)
#
#  conv2d_35 (Conv2D)             (None, 16, 16, 512)  1049088     ['activation_26[0][0]']
#
#  add_5 (Add)                    (None, 16, 16, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  activation_30 (Activation)     (None, 16, 16, 512)  0           ['add_5[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 1)    513         ['activation_30[0][0]']
#
#  activation_31 (Activation)     (None, 16, 16, 1)    0           ['conv2d_37[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 1)   0           ['activation_31[0][0]']
#
#  lambda (Lambda)                (None, 32, 32, 512)  0           ['up_sampling2d_4[0][0]']
#
#  multiply (Multiply)            (None, 32, 32, 512)  0           ['lambda[0][0]',
#                                                                   'activation_26[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 32, 32, 512)  262656      ['multiply[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 32, 32, 1024  0          ['activation_28[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_38[0][0]']
#  ormalization)
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 1536  0           ['up_sampling2d_5[0][0]',
#                                 )                                 'batch_normalization_35[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 32, 32, 512)  7078400     ['concatenate_4[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 32, 32, 512)  786944      ['concatenate_4[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_32[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_40[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 32, 32, 512)  0           ['batch_normalization_38[0][0]',
#                                                                   'batch_normalization_37[0][0]']
#
#  activation_33 (Activation)     (None, 32, 32, 512)  0           ['add_6[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 32, 32, 256)  131328      ['activation_33[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 32, 32, 256)  65792       ['activation_34[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 256)  590080     ['conv2d_44[0][0]']
#  spose)
#
#  conv2d_43 (Conv2D)             (None, 32, 32, 256)  262400      ['activation_24[0][0]']
#
#  add_7 (Add)                    (None, 32, 32, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_43[0][0]']
#
#  activation_35 (Activation)     (None, 32, 32, 256)  0           ['add_7[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 32, 32, 1)    257         ['activation_35[0][0]']
#
#  activation_36 (Activation)     (None, 32, 32, 1)    0           ['conv2d_45[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 64, 64, 1)   0           ['activation_36[0][0]']
#
#  lambda_1 (Lambda)              (None, 64, 64, 256)  0           ['up_sampling2d_6[0][0]']
#
#  multiply_1 (Multiply)          (None, 64, 64, 256)  0           ['lambda_1[0][0]',
#                                                                   'activation_24[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 64, 64, 256)  65792       ['multiply_1[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 64, 64, 512)  0          ['activation_33[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_46[0][0]']
#  ormalization)
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 768)  0           ['up_sampling2d_7[0][0]',
#                                                                   'batch_normalization_40[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 64, 64, 256)  1769728     ['concatenate_5[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 64, 64, 256)  196864      ['concatenate_5[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_37[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_49[0][0]']
#  ormalization)
#
#  batch_normalization_42 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_48[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 64, 64, 256)  0           ['batch_normalization_43[0][0]',
#                                                                   'batch_normalization_42[0][0]']
#
#  activation_38 (Activation)     (None, 64, 64, 256)  0           ['add_8[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 64, 64, 128)  32896       ['activation_38[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 64, 64, 128)  512        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 64, 64, 128)  16512       ['activation_39[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 128)  147584     ['conv2d_52[0][0]']
#  spose)
#
#  conv2d_51 (Conv2D)             (None, 64, 64, 128)  65664       ['activation_22[0][0]']
#
#  add_9 (Add)                    (None, 64, 64, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_51[0][0]']
#
#  activation_40 (Activation)     (None, 64, 64, 128)  0           ['add_9[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 64, 64, 1)    129         ['activation_40[0][0]']
#
#  activation_41 (Activation)     (None, 64, 64, 1)    0           ['conv2d_53[0][0]']
#
#  up_sampling2d_8 (UpSampling2D)  (None, 128, 128, 1)  0          ['activation_41[0][0]']
#
#  lambda_2 (Lambda)              (None, 128, 128, 12  0           ['up_sampling2d_8[0][0]']
#                                 8)
#
#  multiply_2 (Multiply)          (None, 128, 128, 12  0           ['lambda_2[0][0]',
#                                 8)                                'activation_22[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 128, 128, 12  16512       ['multiply_2[0][0]']
#                                 8)
#
#  up_sampling2d_9 (UpSampling2D)  (None, 128, 128, 25  0          ['activation_38[0][0]']
#                                 6)
#
#  batch_normalization_45 (BatchN  (None, 128, 128, 12  512        ['conv2d_54[0][0]']
#  ormalization)                  8)
#
#  concatenate_6 (Concatenate)    (None, 128, 128, 38  0           ['up_sampling2d_9[0][0]',
#                                 4)                                'batch_normalization_45[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 128, 128, 12  442496      ['concatenate_6[0][0]']
#                                 8)
#
#  batch_normalization_46 (BatchN  (None, 128, 128, 12  512        ['conv2d_55[0][0]']
#  ormalization)                  8)
#
#  activation_42 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_46[0][0]']
#                                 8)
#
#  conv2d_57 (Conv2D)             (None, 128, 128, 12  49280       ['concatenate_6[0][0]']
#                                 8)
#
#  conv2d_56 (Conv2D)             (None, 128, 128, 12  147584      ['activation_42[0][0]']
#                                 8)
#
#  batch_normalization_48 (BatchN  (None, 128, 128, 12  512        ['conv2d_57[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_47 (BatchN  (None, 128, 128, 12  512        ['conv2d_56[0][0]']
#  ormalization)                  8)
#
#  add_10 (Add)                   (None, 128, 128, 12  0           ['batch_normalization_48[0][0]',
#                                 8)                                'batch_normalization_47[0][0]']
#
#  activation_43 (Activation)     (None, 128, 128, 12  0           ['add_10[0][0]']
#                                 8)
#
#  conv2d_58 (Conv2D)             (None, 128, 128, 64  8256        ['activation_43[0][0]']
#                                 )
#
#  batch_normalization_49 (BatchN  (None, 128, 128, 64  256        ['conv2d_58[0][0]']
#  ormalization)                  )
#
#  activation_44 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_49[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 128, 128, 64  4160        ['activation_44[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 64  36928      ['conv2d_60[0][0]']
#  spose)                         )
#
#  conv2d_59 (Conv2D)             (None, 128, 128, 64  16448       ['activation_20[0][0]']
#                                 )
#
#  add_11 (Add)                   (None, 128, 128, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_59[0][0]']
#
#  activation_45 (Activation)     (None, 128, 128, 64  0           ['add_11[0][0]']
#                                 )
#
#  conv2d_61 (Conv2D)             (None, 128, 128, 1)  65          ['activation_45[0][0]']
#
#  activation_46 (Activation)     (None, 128, 128, 1)  0           ['conv2d_61[0][0]']
#
#  up_sampling2d_10 (UpSampling2D  (None, 256, 256, 1)  0          ['activation_46[0][0]']
#  )
#
#  lambda_3 (Lambda)              (None, 256, 256, 64  0           ['up_sampling2d_10[0][0]']
#                                 )
#
#  multiply_3 (Multiply)          (None, 256, 256, 64  0           ['lambda_3[0][0]',
#                                 )                                 'activation_20[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 256, 256, 64  4160        ['multiply_3[0][0]']
#                                 )
#
#  up_sampling2d_11 (UpSampling2D  (None, 256, 256, 12  0          ['activation_43[0][0]']
#  )                              8)
#
#  batch_normalization_50 (BatchN  (None, 256, 256, 64  256        ['conv2d_62[0][0]']
#  ormalization)                  )
#
#  concatenate_7 (Concatenate)    (None, 256, 256, 19  0           ['up_sampling2d_11[0][0]',
#                                 2)                                'batch_normalization_50[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 256, 256, 64  110656      ['concatenate_7[0][0]']
#                                 )
#  batch_normalization_51 (BatchN  (None, 256, 256, 64  256        ['conv2d_63[0][0]']
#  ormalization)                  )
#
#  activation_47 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_51[0][0]']
#                                 )
#
#  conv2d_65 (Conv2D)             (None, 256, 256, 64  12352       ['concatenate_7[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 256, 256, 64  36928       ['activation_47[0][0]']
#                                 )
#
#  batch_normalization_53 (BatchN  (None, 256, 256, 64  256        ['conv2d_65[0][0]']
#  ormalization)                  )
#
#  batch_normalization_52 (BatchN  (None, 256, 256, 64  256        ['conv2d_64[0][0]']
#  ormalization)                  )
#
#  add_12 (Add)                   (None, 256, 256, 64  0           ['batch_normalization_53[0][0]',
#                                 )                                 'batch_normalization_52[0][0]']
#
#  activation_48 (Activation)     (None, 256, 256, 64  0           ['add_12[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 256, 256, 1)  65          ['activation_48[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 256, 256, 1)  4          ['conv2d_66[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 256, 256, 1)  0           ['batch_normalization_54[0][0]']
#
# ==================================================================================================
# Total params: 39,090,377
# Trainable params: 39,068,871
# Non-trainable params: 21,506
# __________________________________________________________________________________________________
# None
# C:\Users\Lalitha\miniconda3\envs\tensorflow\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/10
# 79/79 [==============================] - 1976s 25s/step - loss: 0.1102 - accuracy: 0.8859 - jacard_coef: 0.0223 - val_loss: 0.2358 - val_accuracy: 0.9834 - val_jacard_coef: 0.0075
# Epoch 2/10
# 79/79 [==============================] - 1989s 25s/step - loss: 0.0399 - accuracy: 0.9858 - jacard_coef: 0.0283 - val_loss: 0.0393 - val_accuracy: 0.9855 - val_jacard_coef: 0.0242
# Epoch 3/10
# 79/79 [==============================] - 1885s 24s/step - loss: 0.0243 - accuracy: 0.9870 - jacard_coef: 0.0334 - val_loss: 0.0277 - val_accuracy: 0.9835 - val_jacard_coef: 0.0301
# Epoch 4/10
# 79/79 [==============================] - 1934s 24s/step - loss: 0.0180 - accuracy: 0.9873 - jacard_coef: 0.0381 - val_loss: 0.0186 - val_accuracy: 0.9874 - val_jacard_coef: 0.0397
# Epoch 5/10
# 79/79 [==============================] - 1936s 25s/step - loss: 0.0144 - accuracy: 0.9884 - jacard_coef: 0.0446 - val_loss: 0.0172 - val_accuracy: 0.9818 - val_jacard_coef: 0.0494
# Epoch 6/10
# 79/79 [==============================] - 1936s 25s/step - loss: 0.0126 - accuracy: 0.9886 - jacard_coef: 0.0487 - val_loss: 0.0652 - val_accuracy: 0.8957 - val_jacard_coef: 0.0558
# Epoch 7/10
# 79/79 [==============================] - 1939s 25s/step - loss: 0.0109 - accuracy: 0.9897 - jacard_coef: 0.0545 - val_loss: 0.0127 - val_accuracy: 0.9871 - val_jacard_coef: 0.0594
# Epoch 8/10
# 79/79 [==============================] - 1937s 25s/step - loss: 0.0099 - accuracy: 0.9901 - jacard_coef: 0.0590 - val_loss: 0.0191 - val_accuracy: 0.9743 - val_jacard_coef: 0.0678
# Epoch 9/10
# 79/79 [==============================] - 1967s 25s/step - loss: 0.0089 - accuracy: 0.9907 - jacard_coef: 0.0637 - val_loss: 0.0102 - val_accuracy: 0.9899 - val_jacard_coef: 0.0561
# Epoch 10/10
# 79/79 [==============================] - 1934s 24s/step - loss: 0.0082 - accuracy: 0.9912 - jacard_coef: 0.0688 - val_loss: 0.0096 - val_accuracy: 0.9891 - val_jacard_coef: 0.0708
# Attention ResUnet execution time is:  5:23:54.744548
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-68801ef55ffd> in <module>
#     165 # future plotting
#     166 import pandas as pd
# --> 167 unet_history_df = pd.DataFrame(unet_history.history)
#     168 att_unet_history_df = pd.DataFrame(att_unet_history.history)
#     169 att_res_unet_history_df = pd.DataFrame(att_res_unet_history.history)
#
# NameError: name 'unet_history' is not defined
